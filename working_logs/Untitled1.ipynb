# %%
import os 
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import distance
from sklearn.preprocessing import MinMaxScaler

# %%
PATH_IN = r'C:\Users\MI2RL-KHJ\workspace_signal\mit\processed_arr'
os.chdir(PATH_IN)
rpeakList = [i for i in os.listdir(PATH_IN) if i.startswith('correct')]
fxvalList = [i for i in os.listdir(PATH_IN) if i.startswith('filtered')]

# %%
rpeaks = pd.read_csv(rpeakList[0], header=None)

# %%
fxvals = pd.read_csv(fxvalList[0], header=None)

# %%
# min-max normalization 
min_max_scaler = MinMaxScaler()

# %%
fxvals_MinMax = min_max_scaler.fit_transform(fxvals)

# %%
tmp = fxvals_MinMax.tolist()

# %%
flat_list = sum(tmp, [])

# %%
rpeaks = rpeaks[0].tolist()

# %%
# rr_intervals 
rr_intervals_index = []
for r in range(len(rpeaks)):
    if r == len(rpeaks)-1:
        break
    else:         
#     tmp_r = rpeaks[r]
#     tmp_r1 = rpeaks[r+1]
        rr_interval_index = [rpeaks[r], rpeaks[r+1]]
        rr_intervals_index.append(rr_interval_index)

# %%
sum(fxvals_MinMax.tolist(), [])

# %%
tmp = int(fxvals_MinMax.tolist())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-d214891e9193> in <module>
# ----> 1 tmp = int(fxvals_MinMax.tolist())
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'list'

# %%
for rr_interval in rr_intervals_index:
#     rr_intervals = list(range(int(rr_interval[0]),int(rr_interval[1]+1)))
#     fxval_rr = fxvals_MinMax[int(rr_interval[0]):int(rr_interval[1]+1)]
    ftmp = fxvals_MinMax[range(int(rr_interval[0]),int(rr_interval[1]+1))]
    print(ftmp)
    break
# Out:
# [[0.75032461]
#  [0.71576392]
#  [0.64866814]
#  [0.56469985]
#  [0.48278982]
#  [0.41924749]
#  [0.38307927]
#  [0.37417992]
#  [0.38485266]
#  [0.40376925]
#  [0.42058676]
#  [0.42935571]
#  [0.42956541]
#  [0.42480162]
#  [0.42000435]
#  [0.41876891]
#  [0.42188512]
#  [0.42755303]
#  [0.43285854]
#  [0.43555546]
#  [0.43519879]
#  [0.43314204]
#  [0.43156053]
#  [0.43214639]
#  [0.43521426]
#  [0.4396551 ]
#  [0.44367826]
#  [0.44586656]
#  [0.44594499]
#  [0.44486766]
#  [0.44422298]
#  [0.44532066]
#  [0.44846685]
#  [0.45280124]
#  [0.45675176]
#  [0.45884014]
#  [0.45840998]
#  [0.45591805]
#  [0.45267441]
#  [0.45019797]
#  [0.44952766]
#  [0.45081922]
#  [0.45338717]
#  [0.45612235]
#  [0.45804531]
#  [0.45872169]
#  [0.45836549]
#  [0.45762665]
#  [0.4572069 ]
#  [0.45750762]
#  [0.45846826]
#  [0.45964279]
#  [0.46044553]
#  [0.46043308]
#  [0.45949393]
#  [0.45787905]
#  [0.45608443]
#  [0.45465454]
#  [0.45399291]
#  [0.45424578]
#  [0.45528464]
#  [0.45677519]
# ...

# %%
fxvals[77:370]
# Out:
#             0
# 77   0.972367
# 78   0.856586
# 79   0.631811
# 80   0.350512
# 81   0.076109
# ..        ...
# 365  0.159373
# 366  0.394565
# 367  0.643340
# 368  0.868105
# 369  1.027734
#
# [293 rows x 1 columns]

# %%
a= list(range(0,3))

# %%
a = []
# Out:
#   File "<ipython-input-65-d2ab55d969b9>", line 1
#     a = 3:5
#          ^
# SyntaxError: invalid syntax

# %%
rr_interval
# Out:
# [0, 3]

# %%
# 코사인 유사도 함수 
def cos_sim(A, B):
       return dot(A, B)/(norm(A)*norm(B))
